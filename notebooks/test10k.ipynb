# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
# Out:
# /tmp/ipykernel_250450/1781237093.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
# define the base url needed to create the file url.
base_url = "https://www.sec.gov"
headers = {'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/122.0.0.0 Safari/537.36'}



# convert a normal url to a document url
normal_url = "https://www.sec.gov/Archives/edgar/data/72971/0000072971-21-000197.txt"
normal_url = normal_url.replace('-','').replace('.txt','/index.json')

# define a url that leads to a 10k document landing page
documents_url = "https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/index.json"
# documents_url = "https://www.sec.gov/Archives/edgar/data/1265107/000126510719000004/index.json"

# request the url and decode it.
content = requests.get(documents_url, headers=headers).json()

for file in content['directory']['item']:
    
    # Grab the filing summary and create a new url leading to the file so we can download it.
    if file['name'] == 'FilingSummary.xml':

        xml_summary = base_url + content['directory']['name'] + "/" + file['name']
        
        print('-' * 100)
        print('File Name: ' + file['name'])
        print('File Path: ' + xml_summary)
# Out:
# ----------------------------------------------------------------------------------------------------
# File Name: FilingSummary.xml
# File Path: https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/FilingSummary.xml

# %%
# define a new base url that represents the filing folder. This will come in handy when we need to download the reports.
base_url = xml_summary.replace('FilingSummary.xml', '')

# request and parse the content
content = requests.get(xml_summary, headers=headers).content
soup = BeautifulSoup(content, 'lxml')

# find the 'myreports' tag because this contains all the individual reports submitted.
reports = soup.find('myreports')

# I want a list to store all the individual components of the report, so create the master list.
master_reports = []

# loop through each report in the 'myreports' tag but avoid the last one as this will cause an error.
for report in reports.find_all('report')[:-1]:

    # let's create a dictionary to store all the different parts we need.
    report_dict = {}
    report_dict['name_short'] = report.shortname.text
    report_dict['name_long'] = report.longname.text
    report_dict['position'] = report.position.text
    report_dict['category'] = report.menucategory.text
    report_dict['url'] = base_url + report.htmlfilename.text

    # append the dictionary to the master list.
    master_reports.append(report_dict)

    # print the info to the user.
    print('-'*100)
    print(base_url + report.htmlfilename.text)
    print(report.longname.text)
    print(report.shortname.text)
    print(report.menucategory.text)
    print(report.position.text)
# Out:
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R1.htm
# 000010001 - Document - Cover Page
# Cover Page
# Cover
# 1
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R2.htm
# 100010002 - Statement - Consolidated Statement of Income
# Consolidated Statement of Income
# Statements
# 2
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R3.htm
# 100030004 - Statement - Consolidated Statement of Comprehensive Income
# Consolidated Statement of Comprehensive Income
# Statements
# 3
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R4.htm
# 100050006 - Statement - Consolidated Balance Sheet
# Consolidated Balance Sheet
# Statements
# 4
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R5.htm
# 100060007 - Statement - Consolidated Balance Sheet (Parenthetical)
# Consolidated Balance Sheet (Parenthetical)
# Statements
# 5
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R6.htm
# 100070008 - Statement - Consolidated Statement of Changes in Equity
# Consolidated Statement of Changes in Equity
# Statements
# 6
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R7.htm
# 100090010 - Statement - Consolidated Statement of Cash Flows
# Consolidated Statement of Cash Flows
# Statements
# 7
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R8.htm
# 210011001 - Disclosure - Summary of Significant Accounting Policies
# Summary of Significant Accounting Policies
# Notes
# 8
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R9.htm
# 210051002 - Disclosure - Trading Activities
# Trading Activities
# Notes
# 9
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R10.htm
# 210091003 - Disclosure - AFS and HTM Debt Securities
# AFS and HTM Debt Securities
# Notes
# 10
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R11.htm
# 210181004 - Disclosure - Loans and Allowance for Credit Losses
# Loans and Allowance for Credit Losses
# Notes
# 11
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R12.htm
# 210371005 - Disclosure - Leasing Activity
# Leasing Activity
# Notes
# 12
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R13.htm
# 210451006 - Disclosure - Equity Securities
# Equity Securities
# Notes
# 13
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R14.htm
# 210511007 - Disclosure - Premises, Equipment and Other Assets
# Premises, Equipment and Other Assets
# Notes
# 14
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R15.htm
# 210551008 - Disclosure - Securitizations and Variable Interest Entities
# Securitizations and Variable Interest Entities
# Notes
# 15
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R16.htm
# 210641009 - Disclosure - Mortgage Banking Activities
# Mortgage Banking Activities
# Notes
# 16
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R17.htm
# 210701010 - Disclosure - Intangible Assets
# Intangible Assets
# Notes
# 17
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R18.htm
# 210751011 - Disclosure - Deposits
# Deposits
# Notes
# 18
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R19.htm
# 210781012 - Disclosure - Long-Term Debt
# Long-Term Debt
# Notes
# 19
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R20.htm
# 210821013 - Disclosure - Guarantees and Other Commitments
# Guarantees and Other Commitments
# Notes
# 20
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R21.htm
# 210861014 - Disclosure - Pledged Assets and Collateral
# Pledged Assets and Collateral
# Notes
# 21
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R22.htm
# 210911015 - Disclosure - Legal Actions
# Legal Actions
# Notes
# 22
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R23.htm
# 210931016 - Disclosure - Derivatives
# Derivatives
# Notes
# 23
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R24.htm
# 211031017 - Disclosure - Fair Values of Assets and Liabilities
# Fair Values of Assets and Liabilities
# Notes
# 24
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R25.htm
# 211131018 - Disclosure - Preferred Stock
# Preferred Stock
# Notes
# 25
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R26.htm
# 211171019 - Disclosure - Common Stock and Stock Plans
# Common Stock and Stock Plans
# Notes
# 26
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R27.htm
# 211261020 - Disclosure - Revenue from Contracts with Customers
# Revenue from Contracts with Customers
# Notes
# 27
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R28.htm
# 211291021 - Disclosure - Employee Benefits and Other Expenses
# Employee Benefits and Other Expenses
# Notes
# 28
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R29.htm
# 211391022 - Disclosure - Restructuring Charges
# Restructuring Charges
# Notes
# 29
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R30.htm
# 211421023 - Disclosure - Income Taxes
# Income Taxes
# Notes
# 30
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R31.htm
# 211491024 - Disclosure - Earnings Per Common Share
# Earnings Per Common Share
# Notes
# 31
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R32.htm
# 211541025 - Disclosure - Other Comprehensive Income
# Other Comprehensive Income
# Notes
# 32
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R33.htm
# 211581026 - Disclosure - Operating Segments
# Operating Segments
# Notes
# 33
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R34.htm
# 211611027 - Disclosure - Parent-Only Financial Statements
# Parent-Only Financial Statements
# Notes
# 34
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R35.htm
# 211671028 - Disclosure - Regulatory Capital Requirements and Other Restrictions
# Regulatory Capital Requirements and Other Restrictions
# Notes
# 35
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R36.htm
# 220022001 - Disclosure - Summary of Significant Accounting Policies (Policies)
# Summary of Significant Accounting Policies (Policies)
# Policies
# 36
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R37.htm
# 230033001 - Disclosure - Summary of Significant Accounting Policies (Tables)
# Summary of Significant Accounting Policies (Tables)
# Tables
# 37
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R38.htm
# 230063002 - Disclosure - Trading Activities (Tables)
# Trading Activities (Tables)
# Tables
# 38
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R39.htm
# 230103003 - Disclosure - AFS and HTM Debt Securities (Tables)
# AFS and HTM Debt Securities (Tables)
# Tables
# 39
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R40.htm
# 230193004 - Disclosure - Loans and Allowance for Credit Losses (Tables)
# Loans and Allowance for Credit Losses (Tables)
# Tables
# 40
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R41.htm
# 230383005 - Disclosure - Leasing Activity (Tables)
# Leasing Activity (Tables)
# Tables
# 41
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R42.htm
# 230463006 - Disclosure - Equity Securities (Tables)
# Equity Securities (Tables)
# Tables
# 42
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R43.htm
# 230523007 - Disclosure - Premises, Equipment and Other Assets (Tables)
# Premises, Equipment and Other Assets (Tables)
# Tables
# 43
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R44.htm
# 230563008 - Disclosure - Securitizations and Variable Interest Entities (Tables)
# Securitizations and Variable Interest Entities (Tables)
# Tables
# 44
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R45.htm
# 230653009 - Disclosure - Mortgage Banking Activities (Tables)
# Mortgage Banking Activities (Tables)
# Tables
# 45
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R46.htm
# 230713010 - Disclosure - Intangible Assets (Tables)
# Intangible Assets (Tables)
# Tables
# 46
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R47.htm
# 230763011 - Disclosure - Deposits (Tables)
# Deposits (Tables)
# Tables
# 47
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R48.htm
# 230793012 - Disclosure - Long-term Debt (Tables)
# Long-term Debt (Tables)
# Tables
# 48
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R49.htm
# 230833013 - Disclosure - Guarantees and Other Commitments (Tables)
# Guarantees and Other Commitments (Tables)
# Tables
# 49
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R50.htm
# 230873014 - Disclosure - Pledged Assets and Collateral (Tables)
# Pledged Assets and Collateral (Tables)
# Tables
# 50
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R51.htm
# 230943015 - Disclosure - Derivatives (Tables)
# Derivatives (Tables)
# Tables
# 51
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R52.htm
# 231043016 - Disclosure - Fair Values of Assets and Liabilities (Tables)
# Fair Values of Assets and Liabilities (Tables)
# Tables
# 52
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R53.htm
# 231143017 - Disclosure - Preferred Stock (Tables)
# Preferred Stock (Tables)
# Tables
# 53
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R54.htm
# 231183018 - Disclosure - Common Stock and Stock Plans (Tables)
# Common Stock and Stock Plans (Tables)
# Tables
# 54
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R55.htm
# 231273019 - Disclosure - Revenue from Contracts with Customers (Tables)
# Revenue from Contracts with Customers (Tables)
# Tables
# 55
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R56.htm
# 231303020 - Disclosure - Employee Benefits and Other Expenses (Tables)
# Employee Benefits and Other Expenses (Tables)
# Tables
# 56
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R57.htm
# 231403021 - Disclosure - Restructuring Charges (Tables)
# Restructuring Charges (Tables)
# Tables
# 57
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R58.htm
# 231433022 - Disclosure - Income Taxes (Tables)
# Income Taxes (Tables)
# Tables
# 58
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R59.htm
# 231503023 - Disclosure - Earnings Per Common Share (Tables)
# Earnings Per Common Share (Tables)
# Tables
# 59
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R60.htm
# 231553024 - Disclosure - Other Comprehensive Income (Tables)
# Other Comprehensive Income (Tables)
# Tables
# 60
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R61.htm
# 231593025 - Disclosure - Operating Segments (Tables)
# Operating Segments (Tables)
# Tables
# 61
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R62.htm
# 231623026 - Disclosure - Parent-Only Financial Statements (Tables)
# Parent-Only Financial Statements (Tables)
# Tables
# 62
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R63.htm
# 231683027 - Disclosure - Regulatory Capital Requirements and Other Restrictions (Tables)
# Regulatory Capital Requirements and Other Restrictions (Tables)
# Tables
# 63
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R64.htm
# 240044001 - Disclosure - Summary of Significant Accounting Policies (Details)
# Summary of Significant Accounting Policies (Details)
# Details
# 64
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R65.htm
# 240074002 - Disclosure - Trading Assets and Liabilities (Details)
# Trading Assets and Liabilities (Details)
# Details
# 65
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R66.htm
# 240084003 - Disclosure - Trading Activities Net Interest Income and Net Gains (Losses) on Trading Activities (Details)
# Trading Activities Net Interest Income and Net Gains (Losses) on Trading Activities (Details)
# Details
# 66
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R67.htm
# 240114004 - Disclosure - AFS and HTM Debt Securities, Outstanding (Details)
# AFS and HTM Debt Securities, Outstanding (Details)
# Details
# 67
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R68.htm
# 240124005 - Disclosure - AFS and HTM Debt Securities, HTM Debt Securities Purchases and Transfers (Details)
# AFS and HTM Debt Securities, HTM Debt Securities Purchases and Transfers (Details)
# Details
# 68
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R69.htm
# 240134006 - Disclosure - AFS and HTM Debt Securities, Income Statement Impacts (Details)
# AFS and HTM Debt Securities, Income Statement Impacts (Details)
# Details
# 69
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R70.htm
# 240144007 - Disclosure - AFS and HTM Debt Securities, Investment Grade Debt Securities (Details)
# AFS and HTM Debt Securities, Investment Grade Debt Securities (Details)
# Details
# 70
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R71.htm
# 240154008 - Disclosure - AFS and HTM Debt Securities, Gross Unrealized Losses and Fair Value (Details)
# AFS and HTM Debt Securities, Gross Unrealized Losses and Fair Value (Details)
# Details
# 71
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R72.htm
# 240164009 - Disclosure - AFS Debt Securities, Contractual Maturities (Details)
# AFS Debt Securities, Contractual Maturities (Details)
# Details
# 72
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R73.htm
# 240174010 - Disclosure - HTM Debt Securities, Contractual Maturities (Details)
# HTM Debt Securities, Contractual Maturities (Details)
# Details
# 73
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R74.htm
# 240204011 - Disclosure - Loans and Allowance for Credit Losses, Loans Outstanding (Details)
# Loans and Allowance for Credit Losses, Loans Outstanding (Details)
# Details
# 74
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R75.htm
# 240214012 - Disclosure - Loans and Allowance for Credit Losses, Significant Activity (Details)
# Loans and Allowance for Credit Losses, Significant Activity (Details)
# Details
# 75
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R76.htm
# 240224013 - Disclosure - Loans and Allowance for Credit Losses, Commitments to Lend (Details)
# Loans and Allowance for Credit Losses, Commitments to Lend (Details)
# Details
# 76
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R77.htm
# 240234014 - Disclosure - Loans and Allowance for Credit Losses, Allowance for Credit Losses (Details)
# Loans and Allowance for Credit Losses, Allowance for Credit Losses (Details)
# Details
# 77
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R78.htm
# 240244015 - Disclosure - Loans and Allowance for Credit Losses, Allowance for Credit Losses by Category (Details)
# Loans and Allowance for Credit Losses, Allowance for Credit Losses by Category (Details)
# Details
# 78
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R79.htm
# 240254016 - Disclosure - Loans and Allowance for Credit Losses, Loans by Credit Impairment Methodology (Details)
# Loans and Allowance for Credit Losses, Loans by Credit Impairment Methodology (Details)
# Details
# 79
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R80.htm
# 240264017 - Disclosure - Loans and Allowance for Credit Losses, Commercial Loan Categories by Risk Categories and Vintage (Details)
# Loans and Allowance for Credit Losses, Commercial Loan Categories by Risk Categories and Vintage (Details)
# Details
# 80
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R81.htm
# 240274018 - Disclosure - Loans and Allowance for Credit Losses, Loans by Delinquency Status, Commercial (Details)
# Loans and Allowance for Credit Losses, Loans by Delinquency Status, Commercial (Details)
# Details
# 81
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R82.htm
# 240284019 - Disclosure - Loans and Allowance for Credit Losses, Loans by Delinquency Status, Consumer (Details)
# Loans and Allowance for Credit Losses, Loans by Delinquency Status, Consumer (Details)
# Details
# 82
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R83.htm
# 240294020 - Disclosure - Loans and Allowance for Credit Losses, Loans by FICO Score, Consumer (Details)
# Loans and Allowance for Credit Losses, Loans by FICO Score, Consumer (Details)
# Details
# 83
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R84.htm
# 240304021 - Disclosure - Loans and Allowance for Credit Losses, Loans by Loan to Value Ratio, Consumer (Details)
# Loans and Allowance for Credit Losses, Loans by Loan to Value Ratio, Consumer (Details)
# Details
# 84
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R85.htm
# 240314022 - Disclosure - Loans and Allowance for Credit Losses, Nonaccrual (Details)
# Loans and Allowance for Credit Losses, Nonaccrual (Details)
# Details
# 85
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R86.htm
# 240324023 - Disclosure - Loans and Allowance for Credit Losses, 90 Days or More Past Due and Still Accruing (Details)
# Loans and Allowance for Credit Losses, 90 Days or More Past Due and Still Accruing (Details)
# Details
# 86
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R87.htm
# 240334024 - Disclosure - Loans and Allowance for Credit Losses, Impaired Loans (Details)
# Loans and Allowance for Credit Losses, Impaired Loans (Details)
# Details
# 87
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R88.htm
# 240344025 - Disclosure - Loans and Allowance for Credit Losses, Impaired Loans, Average Recorded Investment and Interest Income (Details)
# Loans and Allowance for Credit Losses, Impaired Loans, Average Recorded Investment and Interest Income (Details)
# Details
# 88
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R89.htm
# 240354026 - Disclosure - Loans and Allowance for Credit Losses, Troubled Debt Restructurings Modifications by Type (Details)
# Loans and Allowance for Credit Losses, Troubled Debt Restructurings Modifications by Type (Details)
# Details
# 89
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R90.htm
# 240364027 - Disclosure - Loans and Allowance for Credit Losses, Troubled Debt Restructurings, Current Defaults (Details)
# Loans and Allowance for Credit Losses, Troubled Debt Restructurings, Current Defaults (Details)
# Details
# 90
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R91.htm
# 240394028 - Disclosure - Leasing Activity, Leasing Revenue (Details)
# Leasing Activity, Leasing Revenue (Details)
# Details
# 91
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R92.htm
# 240404029 - Disclosure - Leasing Activity, Investment in Lease Financing (Details)
# Leasing Activity, Investment in Lease Financing (Details)
# Details
# 92
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R93.htm
# 240414030 - Disclosure - Leasing Activity, Maturities of Lease Receivables (Details)
# Leasing Activity, Maturities of Lease Receivables (Details)
# Details
# 93
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R94.htm
# 240424031 - Disclosure - Leasing Activity, Operating Lease Right of Use (ROU) Assets and Lease Liabilities (Details)
# Leasing Activity, Operating Lease Right of Use (ROU) Assets and Lease Liabilities (Details)
# Details
# 94
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R95.htm
# 240434032 - Disclosure - Leasing Activity, Lease Costs (Details)
# Leasing Activity, Lease Costs (Details)
# Details
# 95
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R96.htm
# 240444033 - Disclosure - Leasing Activity, Lease Payments on Operating Leases (Details)
# Leasing Activity, Lease Payments on Operating Leases (Details)
# Details
# 96
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R97.htm
# 240474034 - Disclosure - Equity Securities (Details)
# Equity Securities (Details)
# Details
# 97
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R98.htm
# 240484035 - Disclosure - Equity Securities Net Gains (Losses) from Equity Securities (Details)
# Equity Securities Net Gains (Losses) from Equity Securities (Details)
# Details
# 98
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R99.htm
# 240494036 - Disclosure - Equity Securities Net Gains (Losses) from Measurement Alternative Equity Securities (Details)
# Equity Securities Net Gains (Losses) from Measurement Alternative Equity Securities (Details)
# Details
# 99
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R100.htm
# 240504037 - Disclosure - Equity Securities Measurement Alternative Cumulative Gains (Losses) (Details)
# Equity Securities Measurement Alternative Cumulative Gains (Losses) (Details)
# Details
# 100
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R101.htm
# 240534038 - Disclosure - Premises, Equipment and Other Assets, Premises and Equipment (Details)
# Premises, Equipment and Other Assets, Premises and Equipment (Details)
# Details
# 101
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R102.htm
# 240544039 - Disclosure - Premises, Equipment and Other Assets, Other Assets (Details)
# Premises, Equipment and Other Assets, Other Assets (Details)
# Details
# 102
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R103.htm
# 240574040 - Disclosure - Securitizations and Variable Interest Entities, Transfers with Continuing Involvement (Details)
# Securitizations and Variable Interest Entities, Transfers with Continuing Involvement (Details)
# Details
# 103
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R104.htm
# 240584041 - Disclosure - Securitizations and Variable Interest Entities, Residential Mortgage Servicing Rights (Details)
# Securitizations and Variable Interest Entities, Residential Mortgage Servicing Rights (Details)
# Details
# 104
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R105.htm
# 240594042 - Disclosure - Securitizations and Variable Interest Entities, Securities Held from Nonconforming Mortgage Loan Securitizations (Details)
# Securitizations and Variable Interest Entities, Securities Held from Nonconforming Mortgage Loan Securitizations (Details)
# Details
# 105
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R106.htm
# 240604043 - Disclosure - Securitizations and Variable Interest Entities, Resecuritization Activities (Details)
# Securitizations and Variable Interest Entities, Resecuritization Activities (Details)
# Details
# 106
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R107.htm
# 240614044 - Disclosure - Securitizations and Variable Interest Entities, Off-Balance Sheet Loans Sold or Securitized (Details)
# Securitizations and Variable Interest Entities, Off-Balance Sheet Loans Sold or Securitized (Details)
# Details
# 107
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R108.htm
# 240624045 - Disclosure - Securitizations and Variable Interest Entities, Unconsolidated VIEs (Details)
# Securitizations and Variable Interest Entities, Unconsolidated VIEs (Details)
# Details
# 108
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R109.htm
# 240634046 - Disclosure - Securitizations and Variable Interest Entities, Transactions with Consolidated VIEs (Details)
# Securitizations and Variable Interest Entities, Transactions with Consolidated VIEs (Details)
# Details
# 109
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R110.htm
# 240664047 - Disclosure - Mortgage Banking Activities, Analysis of Changes in Fair Value MSRs (Details)
# Mortgage Banking Activities, Analysis of Changes in Fair Value MSRs (Details)
# Details
# 110
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R111.htm
# 240674048 - Disclosure - Mortgage Banking Activities, Economic Assumptions and Sensitivity of Residential MSRs (Details)
# Mortgage Banking Activities, Economic Assumptions and Sensitivity of Residential MSRs (Details)
# Details
# 111
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R112.htm
# 240684049 - Disclosure - Mortgage Banking Activities, Managed Servicing Portfolio (Details)
# Mortgage Banking Activities, Managed Servicing Portfolio (Details)
# Details
# 112
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R113.htm
# 240694050 - Disclosure - Mortgage Banking Activities, Mortgage Banking Noninterest Income (Details)
# Mortgage Banking Activities, Mortgage Banking Noninterest Income (Details)
# Details
# 113
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R114.htm
# 240724051 - Disclosure - Intangible Assets (Details)
# Intangible Assets (Details)
# Details
# 114
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R115.htm
# 240734052 - Disclosure - Intangible Assets, Amortization Expense (Details)
# Intangible Assets, Amortization Expense (Details)
# Details
# 115
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R116.htm
# 240744053 - Disclosure - Intangible Assets, Allocation of Goodwill to Operating Segments (Details)
# Intangible Assets, Allocation of Goodwill to Operating Segments (Details)
# Details
# 116
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R117.htm
# 240774054 - Disclosure - Deposits (Details)
# Deposits (Details)
# Details
# 117
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R118.htm
# 240804055 - Disclosure - Long-term Debt, Summary (Details)
# Long-term Debt, Summary (Details)
# Details
# 118
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R119.htm
# 240814056 - Disclosure - Long-term Debt, Maturities (Details)
# Long-term Debt, Maturities (Details)
# Details
# 119
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R120.htm
# 240844057 - Disclosure - Guarantees - Carrying Value and Maximum Exposure to Loss (Details)
# Guarantees - Carrying Value and Maximum Exposure to Loss (Details)
# Details
# 120
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R121.htm
# 240854058 - Disclosure - Other Commitments (Details)
# Other Commitments (Details)
# Details
# 121
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R122.htm
# 240884059 - Disclosure - Pledge Assets (Details)
# Pledge Assets (Details)
# Details
# 122
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R123.htm
# 240894060 - Disclosure - Pledged Assets, Offsetting - Securities Financing Activities (Details)
# Pledged Assets, Offsetting - Securities Financing Activities (Details)
# Details
# 123
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R124.htm
# 240904061 - Disclosure - Pledged Assets, Collateral Type and Contractual Maturities of Gross Obligations (Details)
# Pledged Assets, Collateral Type and Contractual Maturities of Gross Obligations (Details)
# Details
# 124
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R125.htm
# 240924062 - Disclosure - Legal Actions (Details)
# Legal Actions (Details)
# Details
# 125
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R126.htm
# 240954063 - Disclosure - Derivatives, Notional or Contractual Amounts and Fair Values of Derivatives (Details)
# Derivatives, Notional or Contractual Amounts and Fair Values of Derivatives (Details)
# Details
# 126
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R127.htm
# 240964064 - Disclosure - Derivatives, Gross Fair Values of Derivative Assets and Liabilities (Details)
# Derivatives, Gross Fair Values of Derivative Assets and Liabilities (Details)
# Details
# 127
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R128.htm
# 240974065 - Disclosure - Derivatives, Gains (Losses) Recognized on Fair Value Hedging Relationships (Details)
# Derivatives, Gains (Losses) Recognized on Fair Value Hedging Relationships (Details)
# Details
# 128
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R129.htm
# 240984066 - Disclosure - Derivatives, Gains (Losses) Recognized on Cash Flow Hedging Relationships (Details)
# Derivatives, Gains (Losses) Recognized on Cash Flow Hedging Relationships (Details)
# Details
# 129
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R130.htm
# 240994067 - Disclosure - Derivatives, Fair Value Hedging Basis Adjustment (Details)
# Derivatives, Fair Value Hedging Basis Adjustment (Details)
# Details
# 130
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R131.htm
# 241004068 - Disclosure - Derivatives, Derivatives Not Designated as Hedging Instruments (Details)
# Derivatives, Derivatives Not Designated as Hedging Instruments (Details)
# Details
# 131
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R132.htm
# 241014069 - Disclosure - Derivatives, Sold and Purchased Credit Derivatives (Details)
# Derivatives, Sold and Purchased Credit Derivatives (Details)
# Details
# 132
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R133.htm
# 241024070 - Disclosure - Derivatives Derivatives, Credit-Risk Contingent Feature Textuals (Details)
# Derivatives Derivatives, Credit-Risk Contingent Feature Textuals (Details)
# Details
# 133
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R134.htm
# 241054071 - Disclosure - Fair Value, Assets and Liabilities, Fair Value on a Recurring Basis (Details)
# Fair Value, Assets and Liabilities, Fair Value on a Recurring Basis (Details)
# Details
# 134
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R135.htm
# 241064072 - Disclosure - Fair Value, Assets and Liabilities, Changes in Level 3 Fair Value Assets and Liabilities on a Recurring Basis (Details)
# Fair Value, Assets and Liabilities, Changes in Level 3 Fair Value Assets and Liabilities on a Recurring Basis (Details)
# Details
# 135
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R136.htm
# 241074073 - Disclosure - Fair Value, Assets and Liabilities, Valuation Techniques - Recurring Basis (Details)
# Fair Value, Assets and Liabilities, Valuation Techniques - Recurring Basis (Details)
# Details
# 136
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R137.htm
# 241084074 - Disclosure - Fair Value, Assets and Liabilities, Fair Value on a Nonrecurring Basis (Details)
# Fair Value, Assets and Liabilities, Fair Value on a Nonrecurring Basis (Details)
# Details
# 137
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R138.htm
# 241094075 - Disclosure - Fair Value, Assets and Liabilities, Changes in Value of Assets with Nonrecurring Fair Value Adjustment (Details)
# Fair Value, Assets and Liabilities, Changes in Value of Assets with Nonrecurring Fair Value Adjustment (Details)
# Details
# 138
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R139.htm
# 241104076 - Disclosure - Fair Value, Assets and Liabilities, Valuation Techniques - Nonrecurring Basis (Details)
# Fair Value, Assets and Liabilities, Valuation Techniques - Nonrecurring Basis (Details)
# Details
# 139
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R140.htm
# 241114077 - Disclosure - Fair Value, Assets and Liabilities, Fair Value Option (Details)
# Fair Value, Assets and Liabilities, Fair Value Option (Details)
# Details
# 140
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R141.htm
# 241124078 - Disclosure - Fair Value, Assets and Liabilities, Fair Value Estimates for Financial Instruments (Details)
# Fair Value, Assets and Liabilities, Fair Value Estimates for Financial Instruments (Details)
# Details
# 141
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R142.htm
# 241154079 - Disclosure - Preferred Stock (Details)
# Preferred Stock (Details)
# Details
# 142
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R143.htm
# 241164080 - Disclosure - ESOP Preferred Stock (Details)
# ESOP Preferred Stock (Details)
# Details
# 143
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R144.htm
# 241194081 - Disclosure - Common Stock and Stock Plans, Common Stock Shares Reserved, Issued and Authorized (Details)
# Common Stock and Stock Plans, Common Stock Shares Reserved, Issued and Authorized (Details)
# Details
# 144
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R145.htm
# 241204082 - Disclosure - Common Stock and Stock Plans, Stock Incentive Compensation Expense (Details)
# Common Stock and Stock Plans, Stock Incentive Compensation Expense (Details)
# Details
# 145
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R146.htm
# 241214083 - Disclosure - Common Stock and Stock Plans, Summary of Restricted Share Rights and Restricted Share Awards (Details)
# Common Stock and Stock Plans, Summary of Restricted Share Rights and Restricted Share Awards (Details)
# Details
# 146
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R147.htm
# 241224084 - Disclosure - Common Stock and Stock Plans, Summary of Performance Awards (Details)
# Common Stock and Stock Plans, Summary of Performance Awards (Details)
# Details
# 147
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R148.htm
# 241234085 - Disclosure - Common Stock and Stock Plans, Director Awards (Details)
# Common Stock and Stock Plans, Director Awards (Details)
# Details
# 148
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R149.htm
# 241244086 - Disclosure - Common Stock and Stock Plans, Stock Option Plans (Details)
# Common Stock and Stock Plans, Stock Option Plans (Details)
# Details
# 149
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R150.htm
# 241254087 - Disclosure - Common Stock and Stock Plans, Employee Stock Ownership Plan (Details)
# Common Stock and Stock Plans, Employee Stock Ownership Plan (Details)
# Details
# 150
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R151.htm
# 241284088 - Disclosure - Revenue from Contracts with Customers, Revenue by Operating Segment (Details)
# Revenue from Contracts with Customers, Revenue by Operating Segment (Details)
# Details
# 151
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R152.htm
# 241314089 - Disclosure - Employee Benefits, Changes in Benefit Obligation and Fair Value of Plan Assets (Details)
# Employee Benefits, Changes in Benefit Obligation and Fair Value of Plan Assets (Details)
# Details
# 152
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R153.htm
# 241324090 - Disclosure - Employee Benefits, Pension Plans With Benefit Obligations in Excess of Plan Assets (Details)
# Employee Benefits, Pension Plans With Benefit Obligations in Excess of Plan Assets (Details)
# Details
# 153
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R154.htm
# 241334091 - Disclosure - Employee Benefits, Net Periodic Benefit Cost and Other Comprehensive Income (Details)
# Employee Benefits, Net Periodic Benefit Cost and Other Comprehensive Income (Details)
# Details
# 154
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R155.htm
# 241344092 - Disclosure - Employee Benefits, Benefits Recognized in Cumulative OCI and Weighted-Average Assumptions in Determining Net Periodic Benefit Cost (Details)
# Employee Benefits, Benefits Recognized in Cumulative OCI and Weighted-Average Assumptions in Determining Net Periodic Benefit Cost (Details)
# Details
# 155
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R156.htm
# 241354093 - Disclosure - Employee Benefits, Projected Benefits Payments (Details)
# Employee Benefits, Projected Benefits Payments (Details)
# Details
# 156
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R157.htm
# 241364094 - Disclosure - Employee Benefits, Pension and Other Benefit Plan Assets (Details)
# Employee Benefits, Pension and Other Benefit Plan Assets (Details)
# Details
# 157
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R158.htm
# 241374095 - Disclosure - Employee Benefits, Fair Value Level 3 Pension and Other Benefit Plan Assets (Details)
# Employee Benefits, Fair Value Level 3 Pension and Other Benefit Plan Assets (Details)
# Details
# 158
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R159.htm
# 241384096 - Disclosure - Employee Benefits and Other Expenses (Details)
# Employee Benefits and Other Expenses (Details)
# Details
# 159
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R160.htm
# 241414097 - Disclosure - Restructuring Charges Accruals (Details)
# Restructuring Charges Accruals (Details)
# Details
# 160
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R161.htm
# 241444098 - Disclosure - Income Taxes, Components of Income Tax Expense (Benefit) (Details)
# Income Taxes, Components of Income Tax Expense (Benefit) (Details)
# Details
# 161
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R162.htm
# 241454099 - Disclosure - Income Taxes, Net Deferred Tax Asset (Liability) (Details)
# Income Taxes, Net Deferred Tax Asset (Liability) (Details)
# Details
# 162
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R163.htm
# 241464100 - Disclosure - Income Taxes, Effective Income Tax Expense (Benefit) and Rate (Details)
# Income Taxes, Effective Income Tax Expense (Benefit) and Rate (Details)
# Details
# 163
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R164.htm
# 241474101 - Disclosure - Income Taxes, Change in Unrecognized Tax Benefits (Details)
# Income Taxes, Change in Unrecognized Tax Benefits (Details)
# Details
# 164
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R165.htm
# 241484102 - Disclosure - Income Taxes, Tax Examination Status (Details)
# Income Taxes, Tax Examination Status (Details)
# Details
# 165
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R166.htm
# 241514103 - Disclosure - Earnings Per Common Share, Calculation of Earnings and Diluted Earnings per Common Share (Details)
# Earnings Per Common Share, Calculation of Earnings and Diluted Earnings per Common Share (Details)
# Details
# 166
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R167.htm
# 241524104 - Disclosure - Earnings Per Common Share, Antidilutive Securities Excluded from the Calculation of Diluted Earnings per Common Share (Details)
# Earnings Per Common Share, Antidilutive Securities Excluded from the Calculation of Diluted Earnings per Common Share (Details)
# Details
# 167
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R168.htm
# 241534105 - Disclosure - Earnings Per Common Share Earnings Per Common Share Dividends Declared Per Common Shares (Details)
# Earnings Per Common Share Earnings Per Common Share Dividends Declared Per Common Shares (Details)
# Details
# 168
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R169.htm
# 241564106 - Disclosure - Other Comprehensive Income, Components of Other Comprehensive Income (Details)
# Other Comprehensive Income, Components of Other Comprehensive Income (Details)
# Details
# 169
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R170.htm
# 241574107 - Disclosure - Other Comprehensive Income, Cumulative OCI Balances (Details)
# Other Comprehensive Income, Cumulative OCI Balances (Details)
# Details
# 170
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R171.htm
# 241604108 - Disclosure - Operating Segments (Details)
# Operating Segments (Details)
# Details
# 171
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R172.htm
# 241634109 - Disclosure - Parent-Only Financial Statements, Parent-Only Statement of Income (Details)
# Parent-Only Financial Statements, Parent-Only Statement of Income (Details)
# Details
# 172
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R173.htm
# 241644110 - Disclosure - Parent-Only Financial Statements, Parent-Only Statement of Comprehensive Income (Details)
# Parent-Only Financial Statements, Parent-Only Statement of Comprehensive Income (Details)
# Details
# 173
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R174.htm
# 241654111 - Disclosure - Parent-Only Financial Statements, Parent-Only Balance Sheet (Details)
# Parent-Only Financial Statements, Parent-Only Balance Sheet (Details)
# Details
# 174
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R175.htm
# 241664112 - Disclosure - Parent-Only Financial Statements, Parent-Only Statement of Cash Flows (Details)
# Parent-Only Financial Statements, Parent-Only Statement of Cash Flows (Details)
# Details
# 175
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R176.htm
# 241694113 - Disclosure - Regulatory and Agency Capital Requirements (Details)
# Regulatory and Agency Capital Requirements (Details)
# Details
# 176
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R177.htm
# 241704114 - Disclosure - Regulatory and Agency Capital Requirements Minimum Required Regulatory Capital Ratios ??? Transition Requirements (Details)
# Regulatory and Agency Capital Requirements Minimum Required Regulatory Capital Ratios ??? Transition Requirements (Details)
# Details
# 177
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R178.htm
# 241714115 - Disclosure - Loan and Dividend Restrictions (Details)
# Loan and Dividend Restrictions (Details)
# Details
# 178
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/72971/000007297121000197/R179.htm
# 241724116 - Disclosure - Cash Restrictions (Details)
# Cash Restrictions (Details)
# Details
# 179
# /tmp/ipykernel_250450/1554867260.py:6: XMLParsedAsHTMLWarning: It looks like you're parsing an XML document using an HTML parser. If this really is an HTML document (maybe it's XHTML?), you can ignore or filter this warning. If it's XML, you should know that using an XML parser will be more reliable. To parse this document as XML, make sure you have the lxml package installed, and pass the keyword argument `features="xml"` into the BeautifulSoup constructor.
#   soup = BeautifulSoup(content, 'lxml')

# %%
# create the list to hold the statement urls
statements_url = []

for report_dict in master_reports:
    
    # define the statements we want to look for.
    item1 = r"Consolidated Balance Sheets"
    item2 = r"Consolidated Statements of Operations and Comprehensive Income (Loss)"
    item3 = r"Consolidated Statements of Cash Flows"
    item4 = r"Consolidated Statements of Stockholder's (Deficit) Equity"
    
    # store them in a list.
    report_list = [item1, item2, item3, item4]
    
    # if the short name can be found in the report list.
    if report_dict['name_short'] in report_list:
        
        # print some info and store it in the statements url.
        print('-'*100)
        print(report_dict['name_short'])
        print(report_dict['url'])
        
        statements_url.append(report_dict['url'])

# %%
# let's assume we want all the statements in a single data set.
statements_data = []

# loop through each statement url
for statement in statements_url:

    # define a dictionary that will store the different parts of the statement.
    statement_data = {}
    statement_data['headers'] = []
    statement_data['sections'] = []
    statement_data['data'] = []
    
    # request the statement file content
    content = requests.get(statement, headers=headers).content
    report_soup = BeautifulSoup(content, 'html')

    # find all the rows, figure out what type of row it is, parse the elements, and store in the statement file list.
    for index, row in enumerate(report_soup.table.find_all('tr')):
        
        # first let's get all the elements.
        cols = row.find_all('td')
        
        # if it's a regular row and not a section or a table header
        if (len(row.find_all('th')) == 0 and len(row.find_all('strong')) == 0): 
            reg_row = [ele.text.strip() for ele in cols]
            statement_data['data'].append(reg_row)
            
        # if it's a regular row and a section but not a table header
        elif (len(row.find_all('th')) == 0 and len(row.find_all('strong')) != 0):
            sec_row = cols[0].text.strip()
            statement_data['sections'].append(sec_row)
            
        # finally if it's not any of those it must be a header
        elif (len(row.find_all('th')) != 0):            
            hed_row = [ele.text.strip() for ele in row.find_all('th')]
            statement_data['headers'].append(hed_row)
            
        else:            
            print('We encountered an error.')

    # append it to the master list.
    statements_data.append(statement_data)

# %%
# Grab the proper components
income_header =  statements_data[1]['headers'][1]
income_data = statements_data[1]['data']

# Put the data in a DataFrame
income_df = pd.DataFrame(income_data)

# Display
print('-'*100)
print('Before Reindexing')
print('-'*100)
display(income_df.head())

# Define the Index column, rename it, and we need to make sure to drop the old column once we reindex.
income_df.index = income_df[0]
income_df.index.name = 'Category'
income_df = income_df.drop(0, axis = 1)

# Display
print('-'*100)
print('Before Regex')
print('-'*100)
display(income_df.head())

# Get rid of the '$', '(', ')', and convert the '' to NaNs.
income_df = income_df.replace('[\$,)]','', regex=True )\
                     .replace( '[(]','-', regex=True)\
                     .replace( '', 'NaN', regex=True)

# Display
print('-'*100)
print('Before type conversion')
print('-'*100)
display(income_df.head())

# everything is a string, so let's convert all the data to a float.
income_df = income_df.astype(float)

# Change the column headers
income_df.columns = income_header

# Display
print('-'*100)
print('Final Product')
print('-'*100)

# show the df
income_df

# drop the data in a CSV file if need be.
# income_df.to_csv('income_state.csv')
# Out:
# <>:26: SyntaxWarning: invalid escape sequence '\$'
# <>:26: SyntaxWarning: invalid escape sequence '\$'
# /tmp/ipykernel_250450/2156104254.py:26: SyntaxWarning: invalid escape sequence '\$'
#   income_df = income_df.replace('[\$,)]','', regex=True )\
# /tmp/ipykernel_250450/2156104254.py:26: SyntaxWarning: invalid escape sequence '\$'
#   income_df = income_df.replace('[\$,)]','', regex=True )\
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[22], line 2
#       1 # Grab the proper components
# ----> 2 income_header =  statements_data[1]['headers'][1]
#       3 income_data = statements_data[1]['data']
#       5 # Put the data in a DataFrame
#
# IndexError: list index out of range
